# %%
# !git clone -b feature/backdoor-accuracy https://github.com/PDSThakur/FL_Wireless_Networks.git
# Out:
# fatal: destination path 'FL_Wireless_Networks' already exists and is not an empty directory.

# %%
# %cd FL_Wireless_Networks
# Out:
# /content/FL_Wireless_Networks

# %%
# !pip install -r requirements.txt

# %%
import torch
print(torch.cuda.is_available(), torch.cuda.get_device_name(0))
# Out:
# True Tesla T4

# %%
# !python run_fedavg.py --dataset cifar10 --num_clients 10 --num_rounds 15 --alpha 0.5 --attack_type semantic --malicious_frac 0.5 --poison_rate 1.0 --fraction_fit 1.0 --backdoor_target_label 0 --semantic_source_label 1 --client_num_gpus 1.0
# Out:
# 2026-04-22 13:28:02.083229: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776864482.104094   11915 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776864482.110961   11915 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776864482.128957   11915 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
